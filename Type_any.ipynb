# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = np.loadtxt('H-H1_GWOSC_4KHZ_R1-1126259447-32.txt')

# %%
t = np.linspace(0,32,a.size)

# %%
plt.figure(dpi = 500)
plt.xlabel('time')
plt.plot(t,a,linewidth = 0.1)
plt.title('GW150914_strain_data')
plt.show()
# Out:
# You got two gold!
